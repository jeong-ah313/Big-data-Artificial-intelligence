# %% [markdown]
# # 네이버 검색 API 서비스

# %% [markdown]
# ## 네이버 서비스 API 신청
#
# 1. 네이버 개발자센터: https://developers.naver.com/products/search/
# 2. 어플리케이션 등록
# 3. 클라이언트 ID/SECRET 확인

# %% [markdown]
# ## NAVER 서비스 API 종류
# | 항목 | 주소                                         |
# |------|----------------------------------------------|
# |블로그| https://openapi.naver.com/v1/search/blog.json |
# |뉴스　| https://openapi.naver.com/v1/search/news.json |
# | 책　 | https://openapi.naver.com/v1/search/book.json|
# | 성인 검색어 판별|　https://openapi.naver.com/v1/search/adult.json|
# | 백과사전| https://openapi.naver.com/v1/search/encyc.json|
# | 영화| https://openapi.naver.com/v1/search/movie.json|
# | 카페글 |https://openapi.naver.com/v1/search/cafearticle.json|
# | 지식in| https://openapi.naver.com/v1/search/kin.json|
# | 지역 | https://openapi.naver.com/v1/search/local.json|
# | 오타변환 | https://openapi.naver.com/v1/search/errata.json|
# | 웹문서 | https://openapi.naver.com/v1/search/webkr.json|
# | 이미지 | https://openapi.naver.com/v1/search/image.json|
# | 쇼핑 | https://openapi.naver.com/v1/search/shop.json|
# | 전문자료 | https://openapi.naver.com/v1/search/doc.json|

# %% [markdown]
# ## 네이버 웹문서 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "agdcSwttWLUq8P2rQNl5"
client_secret = "If8XpM1bm8"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start=1
end=1000

web_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):


  url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index)

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
      remove_tag = re.compile('<.*?>')
      title = re.sub(remove_tag, '', items[item_index]['title'])
      link = items[item_index]['link']
      description = re.sub(remove_tag, '', items[item_index]['description'])
      web_df.loc[idx] = [title, link, description]
      idx += 1
  else:
    print("Error Code:" + rescode)

web_df
# Out:
# 검색 질의: 컴퓨터
#                           Title  ...                                        Description
# 0                  슈퍼컴퓨터 - 나무위키  ...  가장 빠른 슈퍼컴퓨터 연혁 4.2. 대한민국의 슈퍼컴퓨터 도입 4.2.1. 기상청 ...
# 1                          주연테크  ...  주연테크 회사소개 및 컴퓨터,PC,데스크탑,모니터,노트북,태블릿,TV,CCTV 등 ...
# 2                          TG삼보  ...                  컴퓨터, 모니터, 노트북 제조판매 등 제품소개, AS 안내.
# 3                        한글과컴퓨터  ...  한컴오피스, 씽크프리, 전자책, 앱북, 솔루션 제품 체험판, 뷰어 다운로드 및 고객...
# 4                호서대학교 컴퓨터정보공학부  ...  컴퓨터정보공학부 Division of Computer and Information ...
# ..                          ...  ...                                                ...
# 195                  컴퓨터학부 특강안내  ...  【 컴퓨터학부 특강안내 】 컴퓨터학부 조회 : 132 등록일 : 2019-11-21...
# 196  공지사항 &gt;학부공지사항 &gt; 컴퓨터학부  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 95 등록일 : 2019-...
# 197           컴퓨터학부 현장실습(견학) 안내  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 495 등록일 : 2019...
# 198  공지사항 &gt;학부공지사항 &gt; 컴퓨터학부  ...  【 컴퓨터학부 특강안내 】 컴퓨터학부 조회 : 97 등록일 : 2019-11-21 ...
# 199           컴퓨터학부 현장실습(견학) 안내  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 122 등록일 : 2019...
#
# [200 rows x 3 columns]

# %% [markdown]
# ## 네이버 지식iN 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "agdcSwttWLUq8P2rQNl5"
client_secret = "If8XpM1bm8"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start=1
end=1000
sort="sim"

kin_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):


  url = "https://openapi.naver.com/v1/search/kin?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
      remove_tag = re.compile('<.*?>')
      title = re.sub(remove_tag, '', items[item_index]['title'])
      link = items[item_index]['link']
      description = re.sub(remove_tag, '', items[item_index]['description'])
      kin_df.loc[idx] = [title, link, description]
      idx += 1
  else:
    print("Error Code:" + rescode)

kin_df
# Out:
# 검색 질의: 컴퓨터
#                 Title  ...                                        Description
# 0         학점은행제 컴퓨터공학  ...  학점은행제 컴퓨터공학 전공이 있다고 들었습니다. 학점은행제 컴퓨터공학 학사학위를 취...
# 1    컴퓨터의자 적당한 제품이요!!  ...  컴퓨터의자 찾아보고 있는데 다들 이상한거로만 알려주시더라구요.. 그리 비싸지않은 선...
# 2        학점은행제 컴퓨터공학을  ...  학점은행제 컴퓨터공학을 이수하면 학점은행제 컴퓨터공학 학위가 나오나요? 대학교가 아...
# 3             조립식컴퓨터랑  ...  조립식컴퓨터랑 그냥 컴퓨터랑 성능 면에서 차이가 있나요? 질문자님을 뵙게 되어 감사...
# 4     학점은행제 컴퓨터공학 수*업  ...  학점은행제 컴퓨터공학 과정으로 학력개선을 하려는데요. 컴공 계열에서 일을 하고 있어...
# ..                ...  ...                                                ...
# 995    컴퓨터를 장만할려고 합니당  ...  적당한 화질의 온라인 게임이나 cd를 넣을 수 있는 컴퓨터를 살려고 하는데요 일체형...
# 996     컴퓨터 구입 사양과 견적  ...  지금 사용 중인 컴퓨터가 로딩,다운로드 상태가 좋지않고 다운되기도하며 몇일... 게...
# 997          컴퓨터 견적!!  ...  ... 모니터 추천도해주세요 #컴퓨터 #조립식컴퓨터 #견적 #모니터추천 #컴퓨터견적...
# 998       컴퓨터 ssd hdd  ...  컴퓨터를 새로 사려고 하는데 원래 있던 컴퓨터에서 ssd랑 hdd를 새 컴퓨터에 갈...
# 999   컴퓨터가 이러고는 안되요..  ...  컴퓨터가 저것만 빙빙돌고 되질않아요 왜안되죠? 혹시몰라서 컴퓨터 내부사진올려바요.....
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## 네이버 뉴스 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "agdcSwttWLUq8P2rQNl5"
client_secret = "If8XpM1bm8"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start=1
end=1000
sort="sim"

news_df = pd.DataFrame(columns=("Title", "Original Link", "Link", "Description", "Publication Date"))

for start_index in range(start, end, display):


  url = "https://openapi.naver.com/v1/search/news?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
      remove_tag = re.compile('<.*?>')
      title = re.sub(remove_tag, '', items[item_index]['title'])
      original_link = items[item_index]['originallink']
      link = items[item_index]['link']
      description = re.sub(remove_tag, '', items[item_index]['description'])
      pub_date= items[item_index]['pubDate']
      news_df.loc[idx] = [title, original_link, link, description, pub_date]
      idx += 1
  else:
    print("Error Code:" + rescode)

news_df
# Out:
# 검색 질의: 컴퓨터
#                                                Title  ...                 Publication Date
# 0                    [팩트체크] 기상청 슈퍼컴퓨터가 중국산이라 예보 틀린다?  ...  Tue, 11 Aug 2020 21:22:00 +0900
# 1                루닛, 세계 3대 컴퓨터 비전학회 ECCV 상위 5% 논문 선정  ...  Wed, 12 Aug 2020 11:10:00 +0900
# 2                     루닛, 세계 3대 컴퓨터비전학회서 상위 5% 논문 선정  ...  Wed, 12 Aug 2020 17:02:00 +0900
# 3              루닛, 세계 3대 컴퓨터 비전학회 ECCV에서 상위 5% 논문 선정  ...  Wed, 12 Aug 2020 10:25:00 +0900
# 4           수백억원대 슈퍼컴퓨터로도 기상 예측 틀리는 이유는? [임주형의 테크토크]  ...  Wed, 12 Aug 2020 14:03:00 +0900
# ..                                               ...  ...                              ...
# 995                           과기정통부, 슈퍼컴퓨터 CPU 개발 추진  ...  Thu, 26 Mar 2020 11:29:00 +0900
# 996         터치로 컴퓨터 설정을 만질 수 있는 iCUE 넥서스 컴패니언 터치 스크린  ...  Fri, 17 Jul 2020 15:32:00 +0900
# 997                   영진전문대, 컴퓨터정보계열 91.1% 비대면 수업 만족  ...  Thu, 25 Jun 2020 16:16:00 +0900
# 998        인공지능(AI) 교육기반 마련 박차...경북형 미래 컴퓨터교육실 시범 구축  ...  Thu, 09 Jul 2020 09:46:00 +0900
# 999  티랩스-넥슨컴퓨터박물관, &quot;비대면 시대 VR 기반 전시 함께 고민&quot;  ...  Fri, 29 May 2020 16:39:00 +0900
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## 네이버 블로그 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "agdcSwttWLUq8P2rQNl5"
client_secret = "If8XpM1bm8"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start=1
end=1000
sort="sim"

blog_df = pd.DataFrame(columns=("Title", "Link", "Description", "Blogger Name", "Blgger Link", "Post Date"))

for start_index in range(start, end, display):


  url = "https://openapi.naver.com/v1/search/blog?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
      remove_tag = re.compile('<.*?>')
      title = re.sub(remove_tag, '', items[item_index]['title'])
      link = items[item_index]['link']
      description = re.sub(remove_tag, '', items[item_index]['description'])
      blogger_name = items[item_index]['bloggername']
      blogger_link = items[item_index]['bloggerlink']
      post_date = items[item_index]['postdate']
      blog_df.loc[idx] = [title, link, description, blogger_name, blogger_link, post_date]  #언제올렸는지에 대해
      idx += 1
  else:
    print("Error Code:" + rescode)

blog_df
# Out:
# 검색 질의: 컴퓨터
#                                          Title  ... Post Date
# 0                         국비지원컴퓨터학원 현명한 선택이 필수  ...  20200720
# 1                         판교컴퓨터수리 깔끔하게 잘 해주는 곳  ...  20200810
# 2                           컴퓨터학원 국비지원으로 배웠어요!  ...  20200423
# 3                      계리직컴퓨터일반 비전공자의 합격 공부법은?  ...  20200811
# 4                        강남컴퓨터학원 전문가로 성장하는 과정!  ...  20200708
# ..                                         ...  ...       ...
# 995                        [후기] 블루아이티 컴퓨터 구매후기  ...  20191224
# 996       [대학원 컨설팅] 미시간주립대학교 컴퓨터사이언스 전공 박사...   ...  20200804
# 997                       전문가를 위한 솔리드웍스 컴퓨터 사양  ...  20190709
# 998       [미국유학컨설팅] 일리노이 공대(IIT) 컴퓨터 사이언스 취업현황  ...  20200423
# 999  [사용기] 한성컴퓨터 underKG(언더케이지) TFX245 9개월...   ...  20200430
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## 네이버 책 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "agdcSwttWLUq8P2rQNl5"
client_secret = "If8XpM1bm8"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start=1
end=1000
sort="sim"

book_df = pd.DataFrame(columns=("Title", "Link", "Image", "Author", "Price", "Discount", "Publisher", "ISBN", "Description", "Publication Date"))

for start_index in range(start, end, display):


  url = "https://openapi.naver.com/v1/search/book?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
      remove_tag = re.compile('<.*?>')
      title = re.sub(remove_tag, '', items[item_index]['title'])
      link = items[item_index]['link']
      image = items[item_index]['image']
      author = items[item_index]['author']
      price = items[item_index]['price']
      discount = items[item_index]['discount']
      publisher = items[item_index]['publisher']
      isbn = items[item_index]['isbn']
      description = items[item_index]['description']
      pubdate = items[item_index]['pubdate']
      book_df.loc[idx] = [title, link, image, author, price, discount, publisher, isbn, description, pubdate]  #언제올렸는지에 대해
      idx += 1
  else:
    print("Error Code:" + rescode)

blog_df
# Out:
# 검색 질의: 컴퓨터
#                                          Title  ... Post Date
# 0                         국비지원컴퓨터학원 현명한 선택이 필수  ...  20200720
# 1                         판교컴퓨터수리 깔끔하게 잘 해주는 곳  ...  20200810
# 2                           컴퓨터학원 국비지원으로 배웠어요!  ...  20200423
# 3                      계리직컴퓨터일반 비전공자의 합격 공부법은?  ...  20200811
# 4                        강남컴퓨터학원 전문가로 성장하는 과정!  ...  20200708
# ..                                         ...  ...       ...
# 995                        [후기] 블루아이티 컴퓨터 구매후기  ...  20191224
# 996       [대학원 컨설팅] 미시간주립대학교 컴퓨터사이언스 전공 박사...   ...  20200804
# 997                       전문가를 위한 솔리드웍스 컴퓨터 사양  ...  20190709
# 998       [미국유학컨설팅] 일리노이 공대(IIT) 컴퓨터 사이언스 취업현황  ...  20200423
# 999  [사용기] 한성컴퓨터 underKG(언더케이지) TFX245 9개월...   ...  20200430
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## 네이버 영화 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "agdcSwttWLUq8P2rQNl5"
client_secret = "If8XpM1bm8"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start=1
end=1000
sort="sim"

movie_df = pd.DataFrame(columns=("Title", "Link", "Image", "Subtitle", "Publication Date", "Director", "Actor", "User Rating"))

for start_index in range(start, end, display):


  url = "https://openapi.naver.com/v1/search/movie?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
      remove_tag = re.compile('<.*?>')
      title = re.sub(remove_tag, '', items[item_index]['title'])
      link = items[item_index]['link']
      image = items[item_index]['image']
      subtitle = items[item_index]['subtitle']
      pub_date= items[item_index]['pubDate']
      director = items[item_index]['director']
      actor = items[item_index]['actor']
      user_rating = items[item_index]['userRating']
      movie_df.loc[idx] = [title, link, image, subtitle, pub_date, director, actor, user_rating]  #언제올렸는지에 대해
      idx += 1
  else:
    print("Error Code:" + rescode)

movie_df
# Out:
# 검색 질의: 아이언맨
#                    Title  ... User Rating
# 0        엘론 머스크: 리얼 아이언맨  ...        0.00
# 1                   아이언맨  ...        4.95
# 2     아이언맨 &amp; 캡틴 아메리카  ...        9.00
# 3                 아이언맨 3  ...        8.86
# 4    아이언 맨: 라이즈 오브 테크노보어  ...        3.28
# ..                   ...  ...         ...
# 125           인빈서블 아이언 맨  ...        7.24
# 126     특수공작원 아이언맨 - 시리즈  ...        7.63
# 127           특수공작원 아이언맨  ...        9.00
# 128                아이언 맨  ...        5.37
# 129                아이언 맨  ...        7.54
#
# [130 rows x 8 columns]

# %% [markdown]
# ## 네이버 쇼핑 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "agdcSwttWLUq8P2rQNl5"
client_secret = "If8XpM1bm8"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start=1
end=1000
sort="sim"

shop_df = pd.DataFrame(columns=("Title", "Link", "Image", "Low Price", "Hight Price", "Mall Name", "Product ID", "Priduct Type", "Maker", "Brand"))

for start_index in range(start, end, display):


  url = "https://openapi.naver.com/v1/search/shop?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
    response_body = response.read()
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['items']
    for item_index in range(0, len(items)):
      remove_tag = re.compile('<.*?>')
      title = re.sub(remove_tag, '', items[item_index]['title'])
      link = items[item_index]['link']
      image = items[item_index]['image']
      low_price = items[item_index]['lprice']
      high_price= items[item_index]['hprice']
      mall_name = items[item_index]['mallName']
      product_id = items[item_index]['productId']
      product_type = items[item_index]['productType']
      maker = items[item_index]['maker']
      brand = items[item_index]['brand']
      shop_df.loc[idx] = [title, link, image, low_price, high_price, mall_name, product_id, product_type, maker, brand] 
      idx += 1
  else:
    print("Error Code:" + rescode)

shop_df
# Out:
# 검색 질의: 컴퓨터
#                                  Title  ...   Brand
# 0               로스트아크 서든어택 롤 배틀그라운드컴퓨터  ...
# 1                      배틀그라운드 오버워치조립PC  ...
# 2                삼성전자 삼성 DM530ABE-L58A  ...      삼성
# 3                    LG전자 27V70N-GR56K  ...    LG전자
# 4    아싸컴 프리미엄 게이밍 i5-9400F + 외장형 그래픽카드  ...     아싸컴
# ..                                 ...  ...     ...
# 995                한성컴퓨터 보스몬스터 DX5770W  ...   보스몬스터
# 996   레노버 LEGION T530-28ICB 90L300DJKR  ...  LEGION
# 997       ASUS VivoMini VC66-C i5-9400  ...    ASUS
# 998                         시스기어 HE78C  ...    시스기어
# 999         ECS LIVA Q2 N4000 Win10 코잇  ...    LIVA
#
# [1000 rows x 10 columns]
