# %% [markdown]
# # BeautyfulSoup 웹 사이트 순위 스크래핑
#
# * Alexa: https://www.alexa.com/topsites

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank", "Site", "Daily Time on Site", "Daily Pageviews per Visitor", "Daily Pageviews per Visitor", "% of Traffic From Search", " Total Sites Linking In"))

sites = soup.find_all('div', {'class':'tr site-listing'})

for site in sites:
  rank = site.find('div', {'class': 'td'}).get_text()
  website = site.select('p > a')[0].get_text()
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, website, infos, time, pageview, traffic, linking]


rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search  Total Sites Linking In
# 1     1           Google.com  ...                    0.40%               1,635,611
# 2     2          Youtube.com  ...                   15.40%               1,239,944
# 3     3            Baidu.com  ...                    5.10%                 119,631
# 4     4               Qq.com  ...                    3.00%                 293,282
# 5     5         Facebook.com  ...                    8.30%               2,853,499
# 6     6             Sohu.com  ...                    1.60%                  31,869
# 7     7           Taobao.com  ...                    3.20%                  29,514
# 8     8               360.cn  ...                    0.40%                  17,417
# 9     9           Amazon.com  ...                   19.80%                 422,409
# 10   10            Yahoo.com  ...                    7.80%                 375,797
# 11   11               Jd.com  ...                    1.40%                   9,888
# 12   12        Wikipedia.org  ...                   72.80%                 975,317
# 13   13          Sina.com.cn  ...                    2.60%                  56,147
# 14   14            Weibo.com  ...                    2.00%                  80,827
# 15   15           Reddit.com  ...                   28.50%                 208,819
# 16   16             Live.com  ...                   10.80%                  32,985
# 17   17              Zoom.us  ...                   15.70%                   2,761
# 18   18          Netflix.com  ...                    9.50%                  11,763
# 19   19        Xinhuanet.com  ...                    2.80%                  40,531
# 20   20          Okezone.com  ...                    6.50%                  13,068
# 21   21        Microsoft.com  ...                   28.20%                 300,363
# 22   22        Instagram.com  ...                   13.60%                 815,658
# 23   23               Vk.com  ...                    9.20%                 176,377
# 24   24        Myshopify.com  ...                    3.30%                     123
# 25   25           Office.com  ...                    9.30%                   6,434
# 26   26           Alipay.com  ...                    1.40%                   4,048
# 27   27             Csdn.net  ...                    6.80%                   7,697
# 28   28          Yahoo.co.jp  ...                   12.60%                  63,636
# 29   29            Twitch.tv  ...                    6.60%                  11,396
# 30   30        Google.com.hk  ...                    3.10%                   9,270
# 31   31        Bongacams.com  ...                    8.60%                 129,517
# 32   32            Zhanqi.tv  ...                    0.80%                     411
# 33   33             Panda.tv  ...                    0.80%                     397
# 34   34         Blogspot.com  ...                   33.20%                  12,187
# 35   35             Bing.com  ...                    6.00%                  48,846
# 36   36       Aliexpress.com  ...                   13.50%                  24,094
# 37   37             Ebay.com  ...                   15.90%                  85,593
# 38   38            Naver.com  ...                   10.10%                  49,785
# 39   39            Amazon.in  ...                   25.60%                   8,017
# 40   40  Microsoftonline.com  ...                    2.90%                     797
# 41   41         China.com.cn  ...                    1.10%                  15,206
# 42   42            Tianya.cn  ...                    1.00%                   6,929
# 43   43    Stackoverflow.com  ...                   74.50%                  30,804
# 44   44          Twitter.com  ...                   11.50%               2,084,368
# 45   45         Amazon.co.jp  ...                   16.00%                  54,332
# 46   46       Tribunnews.com  ...                   61.70%                  24,701
# 47   47       Chaturbate.com  ...                    9.80%                  66,545
#
# [47 rows x 7 columns]

# %% [markdown]
# ###미국 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites/countries/US"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank", "Site", "Daily Time on Site", "Daily Pageviews per Visitor", "Daily Pageviews per Visitor", "% of Traffic From Search", " Total Sites Linking In"))

sites = soup.find_all('div', {'class':'tr site-listing'})

for site in sites:
  rank = site.find('div', {'class': 'td'}).get_text()
  website = site.select('p > a')[0].get_text()
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, website, infos, time, pageview, traffic, linking]


rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search  Total Sites Linking In
# 1     1           Google.com  ...                    0.40%               1,635,611
# 2     2          Youtube.com  ...                   15.40%               1,239,944
# 3     3           Amazon.com  ...                   19.80%                 422,409
# 4     4            Yahoo.com  ...                    7.80%                 375,797
# 5     5         Facebook.com  ...                    8.30%               2,853,499
# 6     6           Reddit.com  ...                   28.50%                 208,819
# 7     7              Zoom.us  ...                   15.70%                   2,761
# 8     8        Wikipedia.org  ...                   72.80%                 975,317
# 9     9        Myshopify.com  ...                    3.30%                     123
# 10   10             Ebay.com  ...                   15.90%                  85,593
# 11   11          Netflix.com  ...                    9.50%                  11,763
# 12   12             Bing.com  ...                    6.00%                  48,846
# 13   13           Office.com  ...                    9.30%                   6,434
# 14   14             Live.com  ...                   10.80%                  32,985
# 15   15            Twitch.tv  ...                    6.60%                  11,396
# 16   16        Microsoft.com  ...                   28.20%                 300,363
# 17   17            Chase.com  ...                    8.50%                   1,337
# 18   18        Instagram.com  ...                   13.60%                 815,658
# 19   19       Chaturbate.com  ...                    9.80%                  66,545
# 20   20           Zillow.com  ...                   31.60%                  10,506
# 21   21              Cnn.com  ...                   21.60%                 127,176
# 22   22  Microsoftonline.com  ...                    2.90%                     797
# 23   23          Walmart.com  ...                   28.60%                  19,767
# 24   24            Apple.com  ...                   36.80%                 217,585
# 25   25         Linkedin.com  ...                   13.90%                 801,697
# 26   26       Aliexpress.com  ...                   13.50%                  24,094
# 27   27          Dropbox.com  ...                    7.60%                  26,693
# 28   28             Etsy.com  ...                   20.40%                 112,779
# 29   29          Nytimes.com  ...                   28.30%                 184,023
# 30   30       Craigslist.org  ...                   22.50%                  16,256
# 31   31            Adobe.com  ...                   25.00%                 321,467
# 32   32          Twitter.com  ...                   11.50%               2,084,368
# 33   33       Wellsfargo.com  ...                   11.50%                   2,404
# 34   34             Okta.com  ...                    2.90%                     266
# 35   35             Espn.com  ...                   12.00%                  10,635
# 36   36       Livejasmin.com  ...                    3.70%                  12,785
# 37   37            Imgur.com  ...                    7.90%                 259,668
# 38   38             Usps.com  ...                   23.20%                   8,614
# 39   39        Homedepot.com  ...                   44.40%                  13,433
# 40   40       Salesforce.com  ...                    5.90%                   5,115
# 41   41            Force.com  ...                    2.60%                   3,653
# 42   42             Hulu.com  ...                    9.50%                  12,033
# 43   43           Indeed.com  ...                   25.70%                   8,843
# 44   44          Pornhub.com  ...                   26.10%                   4,805
# 45   45               Ca.gov  ...                   31.10%                  46,252
# 46   46             Imdb.com  ...                   47.30%                 163,564
# 47   47              Msn.com  ...                    7.50%                 108,763
# 48   48    Stackoverflow.com  ...                   74.50%                  30,804
# 49   49        Amazonaws.com  ...                    6.70%                  63,761
#
# [49 rows x 7 columns]

# %% [markdown]
# ###한국 웹사이트 순위

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites/countries/KR"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank", "Site", "Daily Time on Site", "Daily Pageviews per Visitor", "Daily Pageviews per Visitor", "% of Traffic From Search", " Total Sites Linking In"))

sites = soup.find_all('div', {'class':'tr site-listing'})

for site in sites:
  rank = site.find('div', {'class': 'td'}).get_text()
  website = site.select('p > a')[0].get_text()
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, website, infos, time, pageview, traffic, linking]


rank_df
# Out:
#    Rank               Site  ... % of Traffic From Search  Total Sites Linking In
# 1     1         Google.com  ...                    0.40%               1,635,611
# 2     2          Naver.com  ...                   10.10%                  49,785
# 3     3        Youtube.com  ...                   15.40%               1,239,944
# 4     4           Daum.net  ...                    5.10%                  18,166
# 5     5        Tistory.com  ...                   25.30%                  10,420
# 6     6          Kakao.com  ...                    8.10%                  13,743
# 7     7       Google.co.kr  ...                   11.10%                   4,950
# 8     8         Amazon.com  ...                   19.80%                 422,409
# 9     9       Facebook.com  ...                    8.30%               2,853,499
# 10   10           Sohu.com  ...                    1.60%                  31,869
# 11   11             Qq.com  ...                    3.00%                 293,282
# 12   12          Namu.wiki  ...                   22.50%                     116
# 13   13        Netflix.com  ...                    9.50%                  11,763
# 14   14        Coupang.com  ...                   13.50%                     477
# 15   15      Wikipedia.org  ...                   72.80%                 975,317
# 16   16         Taobao.com  ...                    3.20%                  29,514
# 17   17             360.cn  ...                    0.40%                  17,417
# 18   18             Jd.com  ...                    1.40%                   9,888
# 19   19          Baidu.com  ...                    5.10%                 119,631
# 20   20       Dcinside.com  ...                   18.80%                     862
# 21   21      Microsoft.com  ...                   28.20%                 300,363
# 22   22          Twitch.tv  ...                    6.60%                  11,396
# 23   23      Gmarket.co.kr  ...                   16.30%                   2,407
# 24   24          Yahoo.com  ...                    7.80%                 375,797
# 25   25      Instagram.com  ...                   13.60%                 815,658
# 26   26          Apple.com  ...                   36.80%                 217,585
# 27   27  Stackoverflow.com  ...                   74.50%                  30,804
# 28   28        Sina.com.cn  ...                    2.60%                  56,147
# 29   29          Weibo.com  ...                    2.00%                  80,827
# 30   30          Nexon.com  ...                   12.30%                     776
# 31   31           Nate.com  ...                    5.30%                   2,637
# 32   32         Office.com  ...                    9.30%                   6,434
# 33   33          Donga.com  ...                   17.20%                   4,705
# 34   34          Adobe.com  ...                   25.00%                 321,467
# 35   35           Bing.com  ...                    6.00%                  48,846
# 36   36         11st.co.kr  ...                    3.70%                   1,381
# 37   37          Yna.co.kr  ...                   14.00%                     586
# 38   38          Joins.com  ...                   23.80%                   5,871
# 39   39        Inven.co.kr  ...                   33.10%                   1,341
# 40   40           Ebay.com  ...                   15.90%                  85,593
# 41   41       Amazon.co.uk  ...                   19.40%                  64,988
# 42   42         Chosun.com  ...                   23.80%                   7,959
# 43   43  Theepochtimes.com  ...                   13.00%                  22,682
# 44   44      Afreecatv.com  ...                    6.20%                     547
# 45   45        Ruliweb.com  ...                   15.90%                     542
# 46   46      Auction.co.kr  ...                   11.50%                   1,445
# 47   47        Dropbox.com  ...                    7.60%                  26,693
#
# [47 rows x 7 columns]
