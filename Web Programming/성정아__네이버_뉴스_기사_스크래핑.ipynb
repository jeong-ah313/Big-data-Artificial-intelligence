# %% [markdown]
# # BeautyfulSoup 네이버 뉴스 기사 스크래핑

# %% [markdown]
# ## 뉴스 기사 스크래핑 함수 정의

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd


def get_news(query, page_num=10):

  news_df = pd.DataFrame(columns=("Title", "Link", "Press", "Datetime", "Article"))
  idx = 0

  url_query =quote(query)
  url = "https://search.naver.com/search.naver?where=news&sm=nws_hty&query=" + url_query
  
  for _ in range(0, page_num):

    search_url = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(search_url, 'html.parser')
    links = soup.find_all('dd', {'class':'txt_inline'})

    for link in links:
      press = link.find('span',{'class':'_sp_each_source'}).get_text()
      news_url = link.find('a').get('href')

      if (news_url == '#'):
        continue
      else:
        news_link = urllib.request.urlopen(news_url).read()
        news_html = BeautifulSoup(news_link, 'html.parser')

        try:
          title = news_html.find('h3', {'id':'articleTitle'}).get_text()
          datetime = news_html.find('span', {'class':'t11'}).get_text()
          article = news_html.find('div', {'id':'articleBodyContents'}).get_text()
          article = article.replace("// flash 오류를 우회하기 위한 함수 추가", "")
          article = article.replace("function _flash_removeCallback() {}", "")
          article = article.replace("\n", "")
          article = article.replace("\t", "")

          news_df.loc[idx]=[title, news_url, press, datetime, article]
          idx += 1
          print('#', end="")
        except:
          continue
          
    try:
      next = soup.find('a',{'class':'next'}).get('href')
      url = "https://search.naver.com/search.naver" + next
    except:
      break

  return news_df

# %%
query = input('검색 질의: ')
news_df = get_news(query, 10)
print('Done')
# Out:
# 검색 질의: 인공지능
# ####################################Done

# %%
news_df
# Out:
#                                                 Title  ...                                            Article
# 0                             광주시, 인공지능 전문업체 3곳과 업무협약  ...  광주시-인공지능 기업 업무협약[광주시 제공.재판매 및 DB 금지](광주=연합뉴스) ...
# 1                        어반베이스, 홈인테리어 AR앱에 '인공지능' 더했다  ...  어반베이스 증강현실(AR) 앱 서비스화면 / 어반베이스[서울경제] 3D 공간데이터 ...
# 2                                인공지능(AI)으로 초등학교 수업을?  ...   이제 수그러지나 싶던 코로나19 신규 확진자 수가 최근 연일 30명 안팎을 기록하...
# 3                                       지방흡입도 인공지능 시대  ...  인공지능(AI) 기술은 4차 산업혁명 시대가 도래하면서 다양한 분야에 응용되고 있다...
# 4                                  [이정규 칼럼] 인공지능과 두려움  ...  (지디넷코리아=이정규  IT컬럼니스트)“공포는 지혜를 찾아가는 길에서 마주치는 첫번...
# 5                             영·호남 이공계특성화대 인공지능 연구 협력  ...  DGIST·GIST '달빛 AI 워크숍' 공동 개최[이데일리 강민구 기자] 영남과 ...
# 6                                  인공지능(AI)으로 영어 배워요!  ...  '2020 초등교육박람회·에듀테크쇼'가 13일 서울 강남구 삼성동 코엑스에서 개막했...
# 7                      메디히어-한양대병원 원격진료 위한 인공지능 개발 MOU  ...  메디히어와 한양대학교 구리병원은 원격진료 서비스 제공을 위한 인공지능(AI) 기술개...
# 8            [AI 사피엔스 시대]ETRI 국가지능화 비전 구현 핵심, 인공지능연구소  ...  한국전자통신연구원(ETRI)한국전자통신연구원(ETRI)의 인공지능연구소(이하 AI ...
# 9                    인공지능 vs 라이더의 직관,  누가 짬뽕을 빨리 배달할까  ...  [디지털데일리 김소영기자] #1. “인공지능이 짜낸 최적의 배달 코스” - 배달앱에...
# 10                국내 최대 인공지능 전시회 'AI 코리아 2020' 부산서 개최  ...  [부산CBS 강동수 기자]부산 대표 마이스 시설인 벡스코에서 국내 최대 규모 인공지...
# 11                  병역 상담 인공지능 챗봇 '아라', 병무청 적극행정 우수사례  ...  24시간 365일 병무민원 상담과 입영 연기 가능[서울=뉴시스] 입영연기 상담 및 ...
# 12                      3차원부터 인공지능까지… 코로나에 대처하는 의류 中企  ...  의류 중견·중소기업들이 코로나에 대처하기 위해 비대면(非對面)에 뛰어들고 있다. 3...
# 13                         KT, 인공지능 연합체 'AI 스터디위크' 개최  ...  KT는 산학연 인공지능(AI) 협력체인 AI 원팀이 이달 21일까지 'AI 스터디 ...
# 14                  트리플렛, 인공지능(AI)기반 무선 소방 방재 솔루션 선보여  ...  [서울경제] (주)트리플렛(대표 신동화)은 양재 aT센터에서 개최되는 ‘2020 소...
# 15                           인공지능 활용 초등학교부터 '수포자' 막는다  ...  교육부·교육감협의회 '교육안전망 강화방안' 발표AI로 초등 국·영·수 지원…중하위권...
# 16                       원자력연, 영상 분석하는 인공지능 국제대회서 준우승  ...  드라마 주인공 대사·감정 등 파악 알고리즘 개발Drama QA 챌린지 예시[한국원자...
# 17                             누구나 집 주변에서 인공지능 교육 받는다  ...  전국민 AI·SW교육 확산방안 발표...전국에 1000곳 역량센터 설립게티이미지뱅크...
# 18                               인공지능이 기획한 전시는 뭐가 다를까  ...  [경향신문] 서울 종로구 두산갤러리에서 인공지능 알고리즘을 바탕으로 작가와 기획자를...
# 19                          부산대, 인공지능 무선 센서 플랫폼 개발 성공  ...  인공지능(AI) 머신 러닝 기술에 초저전력 무선센서 기술을 융합한 AI 기반 초저전...
# 20                                인공지능의 미래, 양재동서 무럭무럭  ...  설립 3돌 앞둔 서울 ‘AI 양재 허브’… 80여개 입주기업이 443명 고용이달 말...
# 21  [AI 사피엔스 시대]이윤근 인공지능연구소장 "AI 관련 전 영역 갖춰...대형 성...  ...  이윤근 한국전자통신연구원(ETRI) 인공지능연구소장“인공지능(AI) 관련 전 영역의...
# 22                             21대 국회 입법지원에 인공지능 활용한다  ...  디지털국회추진단, 'DNA 활용' 목표입법활동 지원시스템 구축 실태조사한달에 100...
# 23                        인공지능으로 버섯 재배…동명대 스마트팜연구소 개소  ...  AI융합스마트팜기술연구소[동명대 제공]    (부산=연합뉴스) 조정호 기자 = 동명...
# 24                     암환자 진단에 인공지능 더하니… ‘사망 시기’까지 예측  ...  서울대의대·국립암센터 연구 결과 발표인공지능으로 암 환자의 삶의 질, 생활습관 등 ...
# 25      인공지능 테크기업 코난테크놀로지, 디지털 뉴딜 확산에 따른 AI 융합 사업 가속화  ...  코난테크놀로지(대표 김영섬)는 한국판 뉴딜 중 D.N.A (Data, Network...
# 26                      국산 인공지능 '엑소브레인' 이제 구어체도 알아듣는다  ...  ETRI "사람의 대화 분석 오류 41% 줄여…API 공개" 엑소브레인 연구하는 E...
# 27                                광주시, 인공지능 조찬 모임 정례화  ...  [KBS 광주]광주시가 인공지능 유망기업과의 조찬 모임을 정기적으로 운영합니다. 광...
# 28                               광주시, 인공지능 조찬포럼 정기 운영  ...  인공지능 산업생태계 조성 교류의 장 마련인공지능 업무협약 기업, 지역기업, 대학, ...
# 29                           해양대, 인공지능 면접 프로그램 서비스 도입  ...  e-스마트 인공지능(AI) 면접 프로그램을 이용 중인 학생. 해양대 제공.한국해양대...
# 30                    대전시·관세청, 인공지능 창업 초기 기업 육성·지원 맞손  ...  디지털 뉴딜사업·지역발전 협력 협약 체결대전시·관세청, 디지털 뉴딜사업·지역발전 협...
# 31                         한국이 미래차·인공지능 싸움에서 뒤처지는 까닭은  ...  전경련 '주요국 신산업 지원 정책 실태와 시사점' 보고서 내놔미래차는 정부 지원 싸...
# 32                          인공지능, “저사람 기침했어요” 콕 찍어 표시  ...  카이스트 연구진, 기침 소리·장소·횟수 식별하는 AI카메라 개발코로나19에 유용한 ...
# 33      ‘AI 양재 허브’ 포스크코로나 시대 세계적인 인공지능 연구·창업 중심지로 발돋움  ...  서울시, ‘입주기업 성장지원’ ‘융합형 인재 양성’ 등 공격적인 신규 사업 펼친다서...
# 34                             KT, '인공지능·디지털혁신 데이' 개최  ...      (서울=연합뉴스) KT가 지난 7일 서울 종로구 광화문 KT스퀘어에서 ABC...
# 35                          올해 에어쇼, 인공지능의 가상 지휘로 만나시죠  ...  존스홉킨스 APL 사전등록 홈페이지미국 국방부 산하 고등연구계획국(DARPA)이 색...
#
# [36 rows x 5 columns]

# %% [markdown]
# ## 뉴스 기사 스크래핑 실행

# %%
news_df['Article']
# Out:
# 0     광주시-인공지능 기업 업무협약[광주시 제공.재판매 및 DB 금지](광주=연합뉴스) ...
# 1     어반베이스 증강현실(AR) 앱 서비스화면 / 어반베이스[서울경제] 3D 공간데이터 ...
# 2      이제 수그러지나 싶던 코로나19 신규 확진자 수가 최근 연일 30명 안팎을 기록하...
# 3     인공지능(AI) 기술은 4차 산업혁명 시대가 도래하면서 다양한 분야에 응용되고 있다...
# 4     (지디넷코리아=이정규  IT컬럼니스트)“공포는 지혜를 찾아가는 길에서 마주치는 첫번...
# 5     DGIST·GIST '달빛 AI 워크숍' 공동 개최[이데일리 강민구 기자] 영남과 ...
# 6     '2020 초등교육박람회·에듀테크쇼'가 13일 서울 강남구 삼성동 코엑스에서 개막했...
# 7     메디히어와 한양대학교 구리병원은 원격진료 서비스 제공을 위한 인공지능(AI) 기술개...
# 8     한국전자통신연구원(ETRI)한국전자통신연구원(ETRI)의 인공지능연구소(이하 AI ...
# 9     [디지털데일리 김소영기자] #1. “인공지능이 짜낸 최적의 배달 코스” - 배달앱에...
# 10    [부산CBS 강동수 기자]부산 대표 마이스 시설인 벡스코에서 국내 최대 규모 인공지...
# 11    24시간 365일 병무민원 상담과 입영 연기 가능[서울=뉴시스] 입영연기 상담 및 ...
# 12    의류 중견·중소기업들이 코로나에 대처하기 위해 비대면(非對面)에 뛰어들고 있다. 3...
# 13    KT는 산학연 인공지능(AI) 협력체인 AI 원팀이 이달 21일까지 'AI 스터디 ...
# 14    [서울경제] (주)트리플렛(대표 신동화)은 양재 aT센터에서 개최되는 ‘2020 소...
# 15    교육부·교육감협의회 '교육안전망 강화방안' 발표AI로 초등 국·영·수 지원…중하위권...
# 16    드라마 주인공 대사·감정 등 파악 알고리즘 개발Drama QA 챌린지 예시[한국원자...
# 17    전국민 AI·SW교육 확산방안 발표...전국에 1000곳 역량센터 설립게티이미지뱅크...
# 18    [경향신문] 서울 종로구 두산갤러리에서 인공지능 알고리즘을 바탕으로 작가와 기획자를...
# 19    인공지능(AI) 머신 러닝 기술에 초저전력 무선센서 기술을 융합한 AI 기반 초저전...
# 20    설립 3돌 앞둔 서울 ‘AI 양재 허브’… 80여개 입주기업이 443명 고용이달 말...
# 21    이윤근 한국전자통신연구원(ETRI) 인공지능연구소장“인공지능(AI) 관련 전 영역의...
# 22    디지털국회추진단, 'DNA 활용' 목표입법활동 지원시스템 구축 실태조사한달에 100...
# 23    AI융합스마트팜기술연구소[동명대 제공]    (부산=연합뉴스) 조정호 기자 = 동명...
# 24    서울대의대·국립암센터 연구 결과 발표인공지능으로 암 환자의 삶의 질, 생활습관 등 ...
# 25    코난테크놀로지(대표 김영섬)는 한국판 뉴딜 중 D.N.A (Data, Network...
# 26    ETRI "사람의 대화 분석 오류 41% 줄여…API 공개" 엑소브레인 연구하는 E...
# 27    [KBS 광주]광주시가 인공지능 유망기업과의 조찬 모임을 정기적으로 운영합니다. 광...
# 28    인공지능 산업생태계 조성 교류의 장 마련인공지능 업무협약 기업, 지역기업, 대학, ...
# 29    e-스마트 인공지능(AI) 면접 프로그램을 이용 중인 학생. 해양대 제공.한국해양대...
# 30    디지털 뉴딜사업·지역발전 협력 협약 체결대전시·관세청, 디지털 뉴딜사업·지역발전 협...
# 31    전경련 '주요국 신산업 지원 정책 실태와 시사점' 보고서 내놔미래차는 정부 지원 싸...
# 32    카이스트 연구진, 기침 소리·장소·횟수 식별하는 AI카메라 개발코로나19에 유용한 ...
# 33    서울시, ‘입주기업 성장지원’ ‘융합형 인재 양성’ 등 공격적인 신규 사업 펼친다서...
# 34        (서울=연합뉴스) KT가 지난 7일 서울 종로구 광화문 KT스퀘어에서 ABC...
# 35    존스홉킨스 APL 사전등록 홈페이지미국 국방부 산하 고등연구계획국(DARPA)이 색...
# Name: Article, dtype: object
