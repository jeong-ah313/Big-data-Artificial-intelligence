# %% [markdown]
# # 케라스 다양한 학습 기술
#
# - 과대적합, 과소적합을 막기 위한 방법들
#   - 모델의 크기 축소
#
#   - 초기화
#
#   - 옵티마이저
#
#   - 배치 정규화
#
#   - 규제화

# %% [markdown]
# ### 모델의 크기 축소
# - 가장 단순한 방법
#
# - 모델의 크기를 줄인다는 것은 **학습 파라미터의 수를 줄이는 것**

# %% [markdown]
# #### 데이터 준비
# - 설명을 위한 코드

# %%
from tensorflow.keras.datasets import imdb
import numpy as np

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

def vectorize_seq(seqs, dim=10000):
  results = np.zeros((len(seqs), dim))
  for i, seq in enumerate(seqs):
    results[i, seq] = 1.

  return results

x_train = vectorize_seq(train_data)
x_test = vectorize_seq(test_data)

y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# #### 2가지의 모델 설정

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model_1 = Sequential([Dense(16, activation='relu', input_shape=(10000, ), name='input'),
                      Dense(16, activation='relu', name='hidden'),
                      Dense(1, activation='sigmoid', name='output')])

# %%
model_1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 16)                160016
# _________________________________________________________________
# hidden (Dense)               (None, 16)                272
# _________________________________________________________________
# output (Dense)               (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2 = Sequential([Dense(7, activation='relu', input_shape=(10000, ), name='input2'),
                      Dense(7, activation='relu', name='hidden2'),
                      Dense(1, activation='sigmoid', name='output2')])

# %%
model_2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input2 (Dense)               (None, 7)                 70007
# _________________________________________________________________
# hidden2 (Dense)              (None, 7)                 56
# _________________________________________________________________
# output2 (Dense)              (None, 1)                 8
# =================================================================
# Total params: 70,071
# Trainable params: 70,071
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_1.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['acc'])

model_2.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['acc'])

# %% [markdown]
# #### 2개의 모델 학습

# %%
model_1_hist = model_1.fit(x_train, y_train,
                           epochs=20,
                           batch_size=512,
                           validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 4s 77ms/step - loss: 0.4768 - acc: 0.8186 - val_loss: 0.3587 - val_acc: 0.8720
# Epoch 2/20
# 49/49 [==============================] - 3s 63ms/step - loss: 0.2724 - acc: 0.9064 - val_loss: 0.3171 - val_acc: 0.8730
# Epoch 3/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.2042 - acc: 0.9293 - val_loss: 0.2873 - val_acc: 0.8848
# Epoch 4/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1710 - acc: 0.9408 - val_loss: 0.3251 - val_acc: 0.8709
# Epoch 5/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1468 - acc: 0.9474 - val_loss: 0.3094 - val_acc: 0.8817
# Epoch 6/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.1285 - acc: 0.9558 - val_loss: 0.3370 - val_acc: 0.8764
# Epoch 7/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.1110 - acc: 0.9619 - val_loss: 0.3711 - val_acc: 0.8724
# Epoch 8/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0975 - acc: 0.9674 - val_loss: 0.3806 - val_acc: 0.8704
# Epoch 9/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0838 - acc: 0.9718 - val_loss: 0.4240 - val_acc: 0.8602
# Epoch 10/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.0737 - acc: 0.9763 - val_loss: 0.4386 - val_acc: 0.8654
# Epoch 11/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.0646 - acc: 0.9792 - val_loss: 0.4795 - val_acc: 0.8562
# Epoch 12/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0537 - acc: 0.9842 - val_loss: 0.5010 - val_acc: 0.8605
# Epoch 13/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0457 - acc: 0.9867 - val_loss: 0.5507 - val_acc: 0.8610
# Epoch 14/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0391 - acc: 0.9893 - val_loss: 0.5740 - val_acc: 0.8596
# Epoch 15/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0319 - acc: 0.9921 - val_loss: 0.6130 - val_acc: 0.8551
# Epoch 16/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0312 - acc: 0.9909 - val_loss: 0.6472 - val_acc: 0.8559
# Epoch 17/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0203 - acc: 0.9955 - val_loss: 0.6882 - val_acc: 0.8552
# Epoch 18/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0180 - acc: 0.9959 - val_loss: 0.7410 - val_acc: 0.8560
# Epoch 19/20
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0160 - acc: 0.9963 - val_loss: 0.7687 - val_acc: 0.8514
# Epoch 20/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0132 - acc: 0.9967 - val_loss: 0.8127 - val_acc: 0.8520

# %%
model_2_hist = model_2.fit(x_train, y_train,
                           epochs=20,
                           batch_size=512,
                           validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 3s 66ms/step - loss: 0.5712 - acc: 0.7117 - val_loss: 0.4612 - val_acc: 0.8655
# Epoch 2/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.3603 - acc: 0.8944 - val_loss: 0.3339 - val_acc: 0.8847
# Epoch 3/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.2562 - acc: 0.9179 - val_loss: 0.2900 - val_acc: 0.8892
# Epoch 4/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.2076 - acc: 0.9299 - val_loss: 0.2812 - val_acc: 0.8904
# Epoch 5/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.1786 - acc: 0.9394 - val_loss: 0.2814 - val_acc: 0.8887
# Epoch 6/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.1576 - acc: 0.9466 - val_loss: 0.2940 - val_acc: 0.8832
# Epoch 7/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.1406 - acc: 0.9536 - val_loss: 0.3006 - val_acc: 0.8838
# Epoch 8/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.1267 - acc: 0.9577 - val_loss: 0.3152 - val_acc: 0.8805
# Epoch 9/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.1150 - acc: 0.9621 - val_loss: 0.3400 - val_acc: 0.8759
# Epoch 10/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.1050 - acc: 0.9659 - val_loss: 0.3538 - val_acc: 0.8734
# Epoch 11/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0962 - acc: 0.9689 - val_loss: 0.3696 - val_acc: 0.8724
# Epoch 12/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0883 - acc: 0.9722 - val_loss: 0.3889 - val_acc: 0.8688
# Epoch 13/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0817 - acc: 0.9742 - val_loss: 0.4055 - val_acc: 0.8689
# Epoch 14/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0746 - acc: 0.9775 - val_loss: 0.4250 - val_acc: 0.8664
# Epoch 15/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0681 - acc: 0.9801 - val_loss: 0.4512 - val_acc: 0.8656
# Epoch 16/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.0625 - acc: 0.9820 - val_loss: 0.4706 - val_acc: 0.8616
# Epoch 17/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0565 - acc: 0.9838 - val_loss: 0.5012 - val_acc: 0.8626
# Epoch 18/20
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0520 - acc: 0.9855 - val_loss: 0.5207 - val_acc: 0.8606
# Epoch 19/20
# 49/49 [==============================] - 2s 44ms/step - loss: 0.0471 - acc: 0.9864 - val_loss: 0.5437 - val_acc: 0.8587
# Epoch 20/20
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0436 - acc: 0.9884 - val_loss: 0.5712 - val_acc: 0.8556

# %% [markdown]
# #### 비교

# %%
epochs = range(1, 21)
model_1_val_loss = model_1_hist.history['val_loss']
model_2_val_loss = model_2_hist.history['val_loss']

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %% [markdown]
# model_2 (더 작은 모델)이 '조금 더 나중에' 과대적합 발생

# %%
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, model_2_val_loss, 'bo', label='Model 2')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 모델의 크기 축소 (2)

# %% [markdown]
# #### 모델 구성

# %%
model_3 = Sequential([Dense(1024, activation='relu', input_shape=(10000, ), name='input3'),
                      Dense(1024, activation='relu', name='hidden3'),
                      Dense(1, activation='sigmoid', name='output3')])

model_3.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['acc'])
model_3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input3 (Dense)               (None, 1024)              10241024
# _________________________________________________________________
# hidden3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# output3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 11,291,649
# Trainable params: 11,291,649
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 모델 학습
# - 시간 소요

# %%
model_3_hist = model_3.fit(x_train, y_train,
                           epochs=20,
                           batch_size=512,
                           validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 25s 513ms/step - loss: 0.5310 - acc: 0.7879 - val_loss: 0.2966 - val_acc: 0.8733
# Epoch 2/20
# 49/49 [==============================] - 23s 463ms/step - loss: 0.2152 - acc: 0.9138 - val_loss: 0.3001 - val_acc: 0.8870
# Epoch 3/20
# 49/49 [==============================] - 23s 469ms/step - loss: 0.1177 - acc: 0.9578 - val_loss: 0.3481 - val_acc: 0.8861
# Epoch 4/20
# 49/49 [==============================] - 24s 499ms/step - loss: 0.0729 - acc: 0.9826 - val_loss: 0.4575 - val_acc: 0.8840
# Epoch 5/20
# 49/49 [==============================] - 23s 465ms/step - loss: 0.1185 - acc: 0.9852 - val_loss: 0.4604 - val_acc: 0.8804
# Epoch 6/20
# 49/49 [==============================] - 23s 466ms/step - loss: 0.0012 - acc: 0.9999 - val_loss: 0.6576 - val_acc: 0.8849
# Epoch 7/20
# 49/49 [==============================] - 23s 463ms/step - loss: 1.0882e-04 - acc: 1.0000 - val_loss: 0.8264 - val_acc: 0.8842
# Epoch 8/20
# 49/49 [==============================] - 23s 465ms/step - loss: 0.2139 - acc: 0.9850 - val_loss: 0.7702 - val_acc: 0.8765
# Epoch 9/20
# 49/49 [==============================] - 23s 468ms/step - loss: 4.7255e-05 - acc: 1.0000 - val_loss: 0.8127 - val_acc: 0.8776
# Epoch 10/20
# 49/49 [==============================] - 23s 475ms/step - loss: 1.2031e-05 - acc: 1.0000 - val_loss: 0.8542 - val_acc: 0.8833
# Epoch 11/20
# 49/49 [==============================] - 23s 467ms/step - loss: 3.2329e-06 - acc: 1.0000 - val_loss: 0.9700 - val_acc: 0.8832
# Epoch 12/20
# 49/49 [==============================] - 23s 467ms/step - loss: 6.6194e-07 - acc: 1.0000 - val_loss: 1.0999 - val_acc: 0.8826
# Epoch 13/20
# 49/49 [==============================] - 23s 465ms/step - loss: 1.3576e-07 - acc: 1.0000 - val_loss: 1.2213 - val_acc: 0.8828
# Epoch 14/20
# 49/49 [==============================] - 23s 469ms/step - loss: 3.4168e-08 - acc: 1.0000 - val_loss: 1.3046 - val_acc: 0.8830
# Epoch 15/20
# 49/49 [==============================] - 23s 466ms/step - loss: 1.5408e-08 - acc: 1.0000 - val_loss: 1.3516 - val_acc: 0.8829
# Epoch 16/20
# 49/49 [==============================] - 23s 467ms/step - loss: 9.7660e-09 - acc: 1.0000 - val_loss: 1.3764 - val_acc: 0.8827
# Epoch 17/20
# 49/49 [==============================] - 23s 466ms/step - loss: 7.2068e-09 - acc: 1.0000 - val_loss: 1.3966 - val_acc: 0.8826
# Epoch 18/20
# 49/49 [==============================] - 23s 464ms/step - loss: 5.7158e-09 - acc: 1.0000 - val_loss: 1.4123 - val_acc: 0.8825
# Epoch 19/20
# 49/49 [==============================] - 23s 465ms/step - loss: 4.7443e-09 - acc: 1.0000 - val_loss: 1.4242 - val_acc: 0.8827
# Epoch 20/20
# 49/49 [==============================] - 23s 462ms/step - loss: 4.0709e-09 - acc: 1.0000 - val_loss: 1.4346 - val_acc: 0.8826

# %% [markdown]
# #### 시각화

# %%
model_3_val_loss = model_3_hist.history['val_loss']

# %%
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, model_2_val_loss, 'bo', label='Model 2')
plt.plot(epochs, model_3_val_loss, 'g--', label='Model 3')

plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# * 볼륨이 큰 신경망일수록 빠르게 훈련데이터 모델링 가능(학습 손실이 낮아짐)
# * 과대 적합에는 더욱 민감해짐
# * 이는 학습-검증 데이터의 손실을 보면 알 수 있음

# %%
model_1_train_loss = model_1_hist.history['loss']
model_2_train_loss = model_2_hist.history['loss']
model_3_train_loss = model_3_hist.history['loss']

plt.plot(epochs, model_1_train_loss, 'r+', label='Model 1')
plt.plot(epochs, model_2_train_loss, 'bo', label='Model 2')
plt.plot(epochs, model_3_train_loss, 'g--', label='Model 3')

plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ### 가중치 초기화

# %% [markdown]
# #### 초기화 전략
#
# - Glorot Initialization (Xavier)
#   - 활성화 함수
#     - 없음
#     - tanh
#     - sigmoid
#     - softmax
#
# - He Initialization
#   - 활성화 함수
#     - ReLU
#     - LeakyReLU
#     - ELU 등

# %%
from tensorflow.keras.layers import Dense, LeakyReLU, Activation
from tensorflow.keras.models import Sequential

# %%
model = Sequential([Dense(30, kernel_initializer='he_normal', input_shape=[10, 10]),
                    LeakyReLU(alpha=0.2),
                    Dense(1, kernel_initializer='he_normal'),
                    Activation("softmax")])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10, 30)            330
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 10, 30)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10, 1)             31
# _________________________________________________________________
# activation (Activation)      (None, 10, 1)             0
# =================================================================
# Total params: 361
# Trainable params: 361
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 고속 옵티마이저

# %% [markdown]
# #### 모멘텀 최적화
#
# $
# \qquad v \ \leftarrow \ \alpha \ v - \gamma \ \frac{\partial L}{\partial W} \\
# \qquad W \ \leftarrow \ W \ + \ v
# $
#
#   - $\alpha\ $ : 관성계수
#
#   - $v$ :  속도
#
#   - $\gamma\ $ : 학습률
#
#   - $\frac{\partial L}{\partial W}\ $ : 손실함수에 대한 미분

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import SGD

# %%
optimizer = SGD(learning_rate=0.001, momentum=0.9)

# %% [markdown]
# #### 네스테로프 (Nesterov)
#
# - 모멘텀의 방향으로 조금 앞선 곳에서 손실함수의 그라디언트를 구함
#
# - 시간이 지날수록 조금 더 빨리 최솟값에 도달
#
# $
# \qquad m \ \leftarrow \  \beta m - \eta \bigtriangledown_\theta J(\theta + \beta m) \\
# \qquad \theta \ \leftarrow \ \theta \ + m
# $
#
#
#   - $h\ $ : 기존 기울기를 제곱하여 더한 값
#
#   - $\eta\ $ : 학습률
#
#   - $\bigtriangledown_\theta J(\theta) \ $ : $\theta$에 대한 미분(그라디언트)
#
#   <img src="https://t1.daumcdn.net/cfile/tistory/99D91C455C76428D11">
#
#   <sub>출처: CS231n</sub>

# %%
optimizer = SGD(learning_rate=0.001, momentum=0.9, nesterov=True)

# %% [markdown]
# #### AdaGrad
#
# - 보통 간단한 모델에는 효과 좋을 수는 있으나, 심층 신경망 모델에서는 사용 X
#
# $
# \qquad h \ \leftarrow \  h + \frac{\partial L}{\partial W} \odot \frac{\partial L}{\partial W} \\
# \qquad W \ \leftarrow \ W \ + \gamma \frac{1}{\sqrt h} \ \frac{\partial L}{\partial W}
# $
#
#   - $h\ $ : 기존 기울기를 제곱하여 더한 값
#
#   - $\gamma\ $ : 학습률
#
#   - $\frac{\partial L}{\partial W}\ $ : $W$에 대한 미분

# %%
from tensorflow.keras.optimizers import Adagrad

# %%
optimizer = Adagrad(learning_rate=0.001)

# %% [markdown]
# #### RMSProp
#
#
# $
# \qquad s \ \leftarrow \ \beta \ s + (1 - \beta) \bigtriangledown_{\theta} J(\theta) \otimes \bigtriangledown_{\theta} J(\theta) \\
# \qquad \theta \ \leftarrow \ \theta \ - \eta  \ \bigtriangledown_{\theta} J(\theta) \oslash \sqrt{s + \epsilon}
# $
#
#   - $s \ $ : 그래디언트의 제곱을 감쇠율을 곱한 후 더함
#
#   - $\eta\ $ : 학습률
#
#   - $\bigtriangledown_{\theta} J(\theta) \ $ : 손실함수의 미분값

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
optimizer = RMSprop(learning_rate=0.001, rho=0.9)

# %% [markdown]
# #### Adam
#
# $
# \qquad m \ \leftarrow \  \beta_1 \ m - (1 - \beta_1)\ \frac{\partial L}{\partial W}  \\
# \qquad s \ \leftarrow \ \beta_2 \ s + (1 - \beta_2) \frac{\partial L}{\partial W} \odot \frac{\partial L}{\partial W} \\
# \qquad \hat{m} \ \leftarrow \frac{m}{1 - \beta_1^t} \\
# \qquad \hat{s} \ \leftarrow \frac{s}{1 - \beta_2^t} \\
# \qquad W \ \leftarrow \ W \ + \gamma \ \hat{m}\  \oslash \sqrt{\hat{s} + \epsilon}
# $
#
#   - $\beta\ $ : 지수 평균의 업데이트 계수
#
#   - $\gamma\ $ : 학습률
#
#   - $\beta_1 \approx 0.9\ ,\ \ \beta_2 \approx 0.999$
#
#   - $\frac{\partial L}{\partial W}\ $ : $W$에 대한 미분

# %%
from tensorflow.keras.optimizers import Adam

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

# %% [markdown]
# ### 배치 정규화
# - 모델에 주입되는 샘플들을 균일하게 만드는 방법
#
# - 학습 후 새로운 데이터에 잘 일반화 할 수 있도록 도와줌
#
# - 데이터 전처리 단계에서 진행해도 되지만 정규화가 되어서 layer에 들어갔다는 보장이 없음
#
# - 주로 **Dense** 또는 **Conv2D** Layer 후, **활성화 함수**이전에 놓임

# %%
from tensorflow.keras.layers import BatchNormalization, Dense, Activation
from tensorflow.keras.utils import plot_model

# %%
model = Sequential()

model.add(Dense(32, input_shape=(28, 28, ), kernel_initializer='he_normal'))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.summary()

plot_model(model, show_shapes=True)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 28, 32)            928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 28, 32)            128
# _________________________________________________________________
# activation_5 (Activation)    (None, 28, 32)            0
# =================================================================
# Total params: 1,056
# Trainable params: 992
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# ### 규제화
# - 복잡한 네트워크 일수록 네트워크의 복잡도에 제한을 두어
#   가중치가 작은 값을 가지도록 함
#
# - 가중치의 분포가 더 균일하게 됨
#
# - 네트워크 손실함수에 큰 가중치에 연관된 비용을 추가
#   - L1 규제 : 가중치의 절댓값에 비례하는 비용이 추가
#   - L2 규제 : 가중치의 제곱에 비례하는 비용이 추가(흔히 가중치 감쇠라고도 불림)
#   - 위 2규제가 합쳐진 경우도 존재

# %% [markdown]
# 데이터는 **모델의 크기** 파트에서 사용된 imdb dataset

# %%
from tensorflow.keras.regularizers import l1, l2, l1_l2

# %% [markdown]
# #### 모델 구성

# %%
l2_model = Sequential([Dense(16, kernel_regularizer=l2(0.001), activation='relu', input_shape=(10000, )),
                       Dense(16, kernel_regularizer=l2(0.001), activation='relu'),
                       Dense(1, activation='sigmoid')])
l2_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])
l2_model.summary()
plot_model(l2_model, show_shapes=True)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 16)                160016
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 모델 학습

# %%
l2_model_hist = l2_model.fit(x_train, y_train,
                             epochs=20,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 2s 48ms/step - loss: 0.4993 - acc: 0.8165 - val_loss: 0.3851 - val_acc: 0.8817
# Epoch 2/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.3213 - acc: 0.9055 - val_loss: 0.3392 - val_acc: 0.8875
# Epoch 3/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2757 - acc: 0.9192 - val_loss: 0.3328 - val_acc: 0.8885
# Epoch 4/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.2549 - acc: 0.9276 - val_loss: 0.3348 - val_acc: 0.8873
# Epoch 5/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2456 - acc: 0.9298 - val_loss: 0.3453 - val_acc: 0.8829
# Epoch 6/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.2355 - acc: 0.9368 - val_loss: 0.3515 - val_acc: 0.8808
# Epoch 7/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2288 - acc: 0.9379 - val_loss: 0.3550 - val_acc: 0.8802
# Epoch 8/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2243 - acc: 0.9386 - val_loss: 0.3624 - val_acc: 0.8787
# Epoch 9/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2195 - acc: 0.9403 - val_loss: 0.3872 - val_acc: 0.8707
# Epoch 10/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2166 - acc: 0.9422 - val_loss: 0.3861 - val_acc: 0.8719
# Epoch 11/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2150 - acc: 0.9441 - val_loss: 0.3843 - val_acc: 0.8729
# Epoch 12/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.2116 - acc: 0.9441 - val_loss: 0.4067 - val_acc: 0.8666
# Epoch 13/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.2063 - acc: 0.9446 - val_loss: 0.4129 - val_acc: 0.8666
# Epoch 14/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.2081 - acc: 0.9442 - val_loss: 0.3921 - val_acc: 0.8720
# Epoch 15/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2063 - acc: 0.9446 - val_loss: 0.4103 - val_acc: 0.8696
# Epoch 16/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.2030 - acc: 0.9466 - val_loss: 0.4072 - val_acc: 0.8697
# Epoch 17/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2014 - acc: 0.9459 - val_loss: 0.4419 - val_acc: 0.8651
# Epoch 18/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2003 - acc: 0.9480 - val_loss: 0.4070 - val_acc: 0.8701
# Epoch 19/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1944 - acc: 0.9490 - val_loss: 0.4321 - val_acc: 0.8668
# Epoch 20/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1945 - acc: 0.9495 - val_loss: 0.4545 - val_acc: 0.8620

# %% [markdown]
# #### 시각화
# - Model 1은 **모델의 크기 축소**파트에서의 모델

# %%
l2_model_val_loss = l2_model_hist.history['val_loss']

epochs = range(1, 21)
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, l2_model_val_loss, 'bo', label='Model L2-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# #### L1과 비교

# %%
l1_model = Sequential([Dense(16, kernel_regularizer=l2(0.0001), activation='relu', input_shape=(10000, )),
                       Dense(16, kernel_regularizer=l2(0.0001), activation='relu'),
                       Dense(1, activation='sigmoid')])
l1_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])
l1_model.summary()
plot_model(l1_model, show_shapes=True)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 16)                160016
# _________________________________________________________________
# dense_14 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
l1_model_hist = l1_model.fit(x_train, y_train,
                             epochs=20,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 4s 76ms/step - loss: 0.4851 - acc: 0.8127 - val_loss: 0.3639 - val_acc: 0.8748
# Epoch 2/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.2848 - acc: 0.9077 - val_loss: 0.3011 - val_acc: 0.8883
# Epoch 3/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.2200 - acc: 0.9268 - val_loss: 0.2951 - val_acc: 0.8874
# Epoch 4/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1889 - acc: 0.9377 - val_loss: 0.2997 - val_acc: 0.8849
# Epoch 5/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1690 - acc: 0.9462 - val_loss: 0.3117 - val_acc: 0.8824
# Epoch 6/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1529 - acc: 0.9529 - val_loss: 0.3262 - val_acc: 0.8792
# Epoch 7/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1421 - acc: 0.9571 - val_loss: 0.3438 - val_acc: 0.8764
# Epoch 8/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1322 - acc: 0.9613 - val_loss: 0.3965 - val_acc: 0.8638
# Epoch 9/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1260 - acc: 0.9638 - val_loss: 0.3780 - val_acc: 0.8714
# Epoch 10/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1155 - acc: 0.9671 - val_loss: 0.4006 - val_acc: 0.8680
# Epoch 11/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1108 - acc: 0.9692 - val_loss: 0.4299 - val_acc: 0.8634
# Epoch 12/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.1024 - acc: 0.9729 - val_loss: 0.4451 - val_acc: 0.8627
# Epoch 13/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1002 - acc: 0.9737 - val_loss: 0.4687 - val_acc: 0.8593
# Epoch 14/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.0961 - acc: 0.9747 - val_loss: 0.4643 - val_acc: 0.8619
# Epoch 15/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.0905 - acc: 0.9774 - val_loss: 0.4817 - val_acc: 0.8613
# Epoch 16/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.0868 - acc: 0.9796 - val_loss: 0.5391 - val_acc: 0.8522
# Epoch 17/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.0809 - acc: 0.9817 - val_loss: 0.5086 - val_acc: 0.8599
# Epoch 18/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.0764 - acc: 0.9841 - val_loss: 0.5580 - val_acc: 0.8527
# Epoch 19/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.0751 - acc: 0.9843 - val_loss: 0.5412 - val_acc: 0.8577
# Epoch 20/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.0706 - acc: 0.9857 - val_loss: 0.5792 - val_acc: 0.8532

# %%
l1_model_val_loss = l1_model_hist.history['val_loss']

epochs = range(1, 21)
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, l1_model_val_loss, 'bo', label='Model L1-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# 3가지 모델 비교
# - Original
# - L1
# - L2

# %%
epochs = range(1, 21)
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, l1_model_val_loss, 'bo', label='Model L1-regularized')
plt.plot(epochs, l1_model_val_loss, 'g--', label='Model L2-regularized')

plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# #### L1, L2와 비교

# %%
l1_l2_model = Sequential([Dense(16, kernel_regularizer=l1_l2(l1=0.0001, l2=0.0001), 
                                activation='relu', input_shape=(10000, )),
                          Dense(16, kernel_regularizer=l1_l2(l1=0.0001, l2=0.0001), 
                                activation='relu'),
                          Dense(1, activation='sigmoid')])
l1_l2_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])
l1_l2_model.summary()
plot_model(l1_l2_model, show_shapes=True)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 16)                160016
# _________________________________________________________________
# dense_20 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
l1_l2_model_hist = l1_l2_model.fit(x_train, y_train,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 4s 91ms/step - loss: 0.5715 - acc: 0.8121 - val_loss: 0.4318 - val_acc: 0.8806
# Epoch 2/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.3814 - acc: 0.8920 - val_loss: 0.3864 - val_acc: 0.8794
# Epoch 3/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.3399 - acc: 0.9031 - val_loss: 0.3774 - val_acc: 0.8825
# Epoch 4/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.3231 - acc: 0.9094 - val_loss: 0.3657 - val_acc: 0.8857
# Epoch 5/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.3131 - acc: 0.9125 - val_loss: 0.3611 - val_acc: 0.8873
# Epoch 6/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.3052 - acc: 0.9154 - val_loss: 0.3701 - val_acc: 0.8843
# Epoch 7/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2958 - acc: 0.9196 - val_loss: 0.3885 - val_acc: 0.8771
# Epoch 8/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2909 - acc: 0.9220 - val_loss: 0.3670 - val_acc: 0.8856
# Epoch 9/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2815 - acc: 0.9250 - val_loss: 0.3790 - val_acc: 0.8808
# Epoch 10/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2784 - acc: 0.9256 - val_loss: 0.3747 - val_acc: 0.8842
# Epoch 11/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2731 - acc: 0.9274 - val_loss: 0.3935 - val_acc: 0.8783
# Epoch 12/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2661 - acc: 0.9320 - val_loss: 0.4432 - val_acc: 0.8606
# Epoch 13/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2668 - acc: 0.9313 - val_loss: 0.3840 - val_acc: 0.8813
# Epoch 14/20
# 49/49 [==============================] - 2s 40ms/step - loss: 0.2561 - acc: 0.9352 - val_loss: 0.3865 - val_acc: 0.8817
# Epoch 15/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2542 - acc: 0.9378 - val_loss: 0.3891 - val_acc: 0.8804
# Epoch 16/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2439 - acc: 0.9406 - val_loss: 0.3909 - val_acc: 0.8776
# Epoch 17/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2383 - acc: 0.9437 - val_loss: 0.4186 - val_acc: 0.8692
# Epoch 18/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2313 - acc: 0.9470 - val_loss: 0.3989 - val_acc: 0.8763
# Epoch 19/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.2238 - acc: 0.9490 - val_loss: 0.4104 - val_acc: 0.8742
# Epoch 20/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.2208 - acc: 0.9510 - val_loss: 0.4277 - val_acc: 0.8730

# %%
l1_l2_model_val_loss = l1_l2_model_hist.history['val_loss']

epochs = range(1, 21)
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, l1_l2_model_val_loss, 'ko', label='Model L1_L2-regularized')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# 4가지 모델 비교
# - Original
#
# - L1
#
# - L2
#
# - L1_L2

# %%
epochs = range(1, 21)
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, l1_model_val_loss, 'bo', label='Model L1-regilarized')
plt.plot(epochs, l2_model_val_loss, 'g--', label='Model L2-regilarized')
plt.plot(epochs, l1_l2_model_val_loss, 'ko', label='Model L1_L2-regularized')

plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ### 드롭아웃(Dropout)
# - 신경망을 위해 사용되는 규제 기법 중 가장 효과적이고 널리 사용되는 방법
#
# - 신경망의 레이어에 드롭아웃을 적용하면 훈련하는 동안 무작위로 층의 일부 특성(노드)를 제외
#   - 예를 들어, [1.0, 3.2, 0.6, 0.8, 1.1] 라는 벡터에 대해 드롭아웃을 적용하면 **무작위로 0으로 바뀜**
#     $\rightarrow$ [0, 3.2, 0.6, 0.8, 0]
#
#   - 보통 0.2 ~ 0.5 사이의 비율로 지정됨
#
# - 테스트 단계에서는 그 어떤 노드도 드롭아웃 되지 않는다.
#   - 대신 해당 레이어의 출력 노드를 드롭아웃 비율에 맞게 줄여줌

# %%
from tensorflow.keras.layers import Dropout

# %% [markdown]
# #### 모델 구성

# %%
dropout_model = Sequential([Dense(16, activation='relu', input_shape=(10000, )),
                            Dropout(0.5),
                            Dense(16, activation='relu'),
                            Dropout(0.5),
                            Dense(1, activation='sigmoid')])

dropout_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])

dropout_model.summary()
plot_model(dropout_model, show_shapes=True)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 16)                160016
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 16)                272
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 모델 학습

# %%
dropout_model_hist = dropout_model.fit(x_train, y_train,
                                        epochs=20,
                                        batch_size=512,
                                        validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 4s 85ms/step - loss: 0.5712 - acc: 0.6964 - val_loss: 0.4107 - val_acc: 0.8670
# Epoch 2/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.4165 - acc: 0.8326 - val_loss: 0.3198 - val_acc: 0.8825
# Epoch 3/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.3320 - acc: 0.8774 - val_loss: 0.2844 - val_acc: 0.8884
# Epoch 4/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.2813 - acc: 0.8967 - val_loss: 0.2769 - val_acc: 0.8881
# Epoch 5/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.2474 - acc: 0.9107 - val_loss: 0.2863 - val_acc: 0.8887
# Epoch 6/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.2224 - acc: 0.9222 - val_loss: 0.3094 - val_acc: 0.8852
# Epoch 7/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.2019 - acc: 0.9293 - val_loss: 0.3103 - val_acc: 0.8842
# Epoch 8/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1830 - acc: 0.9370 - val_loss: 0.3434 - val_acc: 0.8848
# Epoch 9/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1730 - acc: 0.9396 - val_loss: 0.3519 - val_acc: 0.8835
# Epoch 10/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1540 - acc: 0.9479 - val_loss: 0.3859 - val_acc: 0.8824
# Epoch 11/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1510 - acc: 0.9481 - val_loss: 0.4247 - val_acc: 0.8807
# Epoch 12/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1453 - acc: 0.9491 - val_loss: 0.4316 - val_acc: 0.8801
# Epoch 13/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1387 - acc: 0.9527 - val_loss: 0.4414 - val_acc: 0.8770
# Epoch 14/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1351 - acc: 0.9532 - val_loss: 0.4672 - val_acc: 0.8760
# Epoch 15/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1246 - acc: 0.9563 - val_loss: 0.4933 - val_acc: 0.8766
# Epoch 16/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1238 - acc: 0.9580 - val_loss: 0.5249 - val_acc: 0.8772
# Epoch 17/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1201 - acc: 0.9587 - val_loss: 0.5495 - val_acc: 0.8759
# Epoch 18/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1206 - acc: 0.9570 - val_loss: 0.5499 - val_acc: 0.8733
# Epoch 19/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1160 - acc: 0.9615 - val_loss: 0.5701 - val_acc: 0.8726
# Epoch 20/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.1152 - acc: 0.9594 - val_loss: 0.6101 - val_acc: 0.8740

# %% [markdown]
# #### 시각화

# %%
dropout_model_val_loss = dropout_model_hist.history['val_loss']

epochs = range(1, 21)
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, dropout_model_val_loss, 'co', label='Modeldropout')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

plt.show()
