# %% [markdown]
# # Image Stitching
#
# - 영상 이어 붙이기
#
# - Image Stitching Algorithm (참고)
#
#   <img src="https://docs.opencv.org/3.4/StitchingPipeline.jpg">
#
#   [이미지 출처] https://docs.opencv.org/3.4/d1/d46/group__stitching.html
#
# <br>
#
# - `cv2.create()`
#
#   - `Parameters`
#
#     - `mode` : 이어붙이기 방식
#
#       - `PANORAMA`
#
#       - `SCANS`
#   - `반환값` : stitcher 객체
#
# - `cv2.stitch()`
#
#   - `Parameters`
#
#     - `images` : 입력 영상의 벡터
#
#     - `pano` : 출력 파노라마 영상
#
#   - `반환값` : 함수 동작 결과 코드

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
imgs = []

# %%
img1 = cv2.imread('/path/to/your/image1')
img2 = cv2.imread('/path/to/your/image2')

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=920x688 at 0x7FAF0A50AE80>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=926x694 at 0x7FAF09C08550>

# %%
imgs.append(img1)
imgs.append(img2)

# %%
len(imgs)
# Out:
# 2

# %%
stitcher = cv2.Stitcher_create()

# %%
status, dst = stitcher.stitch(imgs)

# %%
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=1217x730 at 0x7FAF083C0630>
