# %% [markdown]
# # 입력과 출력

# %% [markdown]
# ---

# %% [markdown]
# ## 표준 입출력(Standard Input/Output)

# %% [markdown]
# ### 표준 입력 함수

# %%
name=input("이름: ")
print(name)
# Out:
# 이름: 성정아
# 성정아

# %% [markdown]
# #### [Lab] 섭씨 온도를 화씨 온도로 변환
#
# * 섭씨 온도를 화씨 온도로 변환하는 공식: $F = (C * 1.8) + 32$

# %%
celsius=float(input("섭씨온도:"))
fahrenheit=(celsius*1.8)+32
print("화씨온도:",fahrenheit)
# Out:
# 섭씨온도:28
# 화씨온도: 82.4

# %% [markdown]
# #### [Lab] 구구단 중의 하나의 단을 입력받아 계산
#
# * 출력할 단을 입력
# * 해당 단의 계산 결과 출력

# %%
i=int(input("출력할 단:"))
for j in range(1,10):
  print("{0}x{1}={2}".format(i,j,i*j))
# Out:
# 출력할 단:9
# 9x1=9
# 9x2=18
# 9x3=27
# 9x4=36
# 9x5=45
# 9x6=54
# 9x7=63
# 9x8=72
# 9x9=81

# %% [markdown]
# ### 표준 출력 함수

# %%
print("Hello Python")
print("안녕 파이썬")
print(7)
print(3.14)
print([1,2,3])

print("Hello","Python",sep="---")
print(1, 2, 3)
print(1, end=' ')
print(2, end=' ')
print(3, end=' ')
# Out:
# Hello Python
# 안녕 파이썬
# 7
# 3.14
# [1, 2, 3]
# Hello---Python
# 1 2 3
# 1 2 3

# %% [markdown]
# #### [Lab] 구구단 출력
#
# * `print()` 함수를 사용하여 각 단마다 횡으로 출력

# %%
for i in range(2,10):
  for j in range(1,10):
    print("{0}x{1}={2}".format(i,j,i*j),end='\t')
    print()
# Out:
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
# 3x1=3
# 3x2=6
# 3x3=9
# 3x4=12
# 3x5=15
# 3x6=18
# 3x7=21
# 3x8=24
# 3x9=27
# 4x1=4
# 4x2=8
# 4x3=12
# 4x4=16
# 4x5=20
# 4x6=24
# 4x7=28
# 4x8=32
# 4x9=36
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
# 6x1=6
# 6x2=12
# 6x3=18
# 6x4=24
# 6x5=30
# 6x6=36
# 6x7=42
# 6x8=48
# 6x9=54
# 7x1=7
# 7x2=14
# 7x3=21
# 7x4=28
# 7x5=35
# 7x6=42
# 7x7=49
# 7x8=56
# 7x9=63
# 8x1=8
# 8x2=16
# 8x3=24
# 8x4=32
# 8x5=40
# 8x6=48
# 8x7=56
# 8x8=64
# 8x9=72
# 9x1=9
# 9x2=18
# 9x3=27
# 9x4=36
# 9x5=45
# 9x6=54
# 9x7=63
# 9x8=72
# 9x9=81

# %% [markdown]
# ---

# %% [markdown]
# ## 파일 입출력(File Input/Output)

# %% [markdown]
# ### 파일 입출력 과정
#
# * 파일의 입출력 과정은 단계를 가짐
# * 파일을 열고, 파일을 읽거나 쓰고, 파일을 닫는 순서

# %% [markdown]
# ### 파일 열기/닫기
#
# * file.txt 파일을 생성하고, 열고 닫기

# %%
#파일을 열고 닫는 과정은 앞과 끝에 꼭 있어야함
f=open("file.txt",'w')
f=open("file.txt",'r')
f.close()

# %%
# !ls file.txt
# Out:
# file.txt

# %% [markdown]
# ### 파일 모드(File Mode)

# %% [markdown]
# ### 텍스트 파일 쓰기

# %% [markdown]
# #### write()
#
# * `write()`를 이용하여 파일에 쓰기

# %%
f=open("file.txt",'w')
f.write("Hello Python")
f.close()

# %%
# !cat file.txt
# Out:
# Hello Python

# %% [markdown]
# #### writelines()
#
# * `writelines()`를 이용하여 list를 파일에 쓰기

# %%
list=["One\n","Two\n",'Three\n']
f=open("file.txt",'w')
f.writelines(list)
f.close()

# %%
# !cat file.txt
# Out:
# One
# Two
# Three

# %% [markdown]
# #### 표준 입력 → 파일 쓰기
#
# * 표준 입력을 `input()` 함수를 통해 입력 받고, `write()` 함수를 통해 파일에 쓰기

# %%
text=input("입력:")
f=open("file.txt",'w')
f.write(text)
f.close()
#표준입력에서 받아서 파일에 저장해서 쓴다.
# Out:
# 입력:성정아

# %%
# !cat file.txt
# Out:
# 성정아

# %%
text=[str(text + '\n') for text in input("여러 값 입력:").split()]
f=open("file.txt",'w')
f.writelines(text)
f.close()
# Out:
# 여러 값 입력:1 2 3 4 5

# %%
# !cat file.txt
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x=""
text=""
while x != 'q':
  x=input("반복 입력:")
  text += x+ '\n'

f=open("file.txt",'w')
f.writelines(text)
f.close()
# Out:
# 반복 입력:1
# 반복 입력:2
# 반복 입력:3
# 반복 입력:4
# 반복 입력:5
# 반복 입력:q

# %%
# !cat file.txt
# Out:
# 1
# 2
# 3
# 4
# 5
# q

# %% [markdown]
# ### [Lab] 구구단 결과를 파일에 쓰기
#
# * 구구단 결과를 파일에 쓰기

# %%
f = open("dan.txt", 'w')
for i in range(2,10):
  for j in range(1,10):
    f.write("{0}x{1}={2}\n".format(i,j,i*j))
  else:
    f.write("\n")
  
  f.close

# %%
# !cat dan.txt
# Out:
# 2x1=2
# 2x2=4
# 2x3=6
# 2x4=8
# 2x5=10
# 2x6=12
# 2x7=14
# 2x8=16
# 2x9=18
#
# 3x1=3
# 3x2=6
# 3x3=9
# 3x4=12
# 3x5=15
# 3x6=18
# 3x7=21
# 3x8=24
# 3x9=27
#
# 4x1=4
# 4x2=8
# 4x3=12
# 4x4=16
# 4x5=20
# 4x6=24
# 4x7=28
# 4x8=32
# 4x9=36
#
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
#
# 6x1=6
# 6x2=12
# 6x3=18
# 6x4=24
# 6x5=30
# 6x6=36
# 6x7=42
# 6x8=48
# 6x9=54
#
# 7x1=7
# 7x2=14
# 7x3=21
# 7x4=28
# 7x5=35
# 7x6=42
# 7x7=49
# 7x8=56
# 7x9=63
#
# 8x1=8
# 8x2=16
# 8x3=24
# 8x4=32
# 8x5=40
# 8x6=48
# 8x7=56
# 8x8=64
# 8x9=72
#
# 9x1=9
# 9x2=18
# 9x3=27
# 9x4=36
# 9x5=45
# 9x6=54
# 9x7=63
# 9x8=72
# 9x9=81

# %% [markdown]
# ### 텍스트 파일 출력

# %% [markdown]
# * 텍스트 파일 예제

# %%
# !echo "동해물과 백두산이 마르고 닳도록" > anthem.txt
# !echo "하느님이 보우하사 우리 나라 만세" >> anthem.txt

# %% [markdown]
# #### readline()
#
# * `readline()`를 이용하여 텍스트 파일을 라인 단위로 읽고 화면에 출력

# %%
f=open("anthem.txt",'r')
while True:
  line = f.readline() #한줄씩 가지고 와서 보고
  if not line:break # 라인이 없으면 글이 없으면 break
  print(line)

f.close
# Out:
# 동해물과 백두산이 마르고 닳도록
#
# 하느님이 보우하사 우리 나라 만세
# <function TextIOWrapper.close>

# %% [markdown]
# #### readlines()
#
# * `readlines()`를 이용하여 텍스트 파일의 여러 라인을 읽고 화면에 출력

# %%
f=open("anthem.txt",'r')
lines=f.readlines()
print(lines)
f.close()
# Out:
# ['동해물과 백두산이 마르고 닳도록\n', '하느님이 보우하사 우리 나라 만세\n']

# %% [markdown]
# #### read()
#
# * `read()`를 이용하여 텍스트 파일을 읽고 화면에 출력

# %%
f=open("anthem.txt",'r')
data=f.read()
print(data)
f.close()
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리 나라 만세

# %% [markdown]
# #### tell()
#
# * 파일 포인터 위치 변경

# %%
f=open("anthem.txt",'r')
while True:
  print(f.tell())
  line=f.readline()
  if not line: break
  print(line)

f.close()
# Out:
# 0
# 동해물과 백두산이 마르고 닳도록
#
# 46
# 하느님이 보우하사 우리 나라 만세
#
# 93

# %% [markdown]
# #### seek()
#
# * 파일 포인터 위치 이동

# %%
#파일의 위치를 바꿔서

f=open("anthem.txt",'r')
f.seek(46)
line=f.readline()
print(line)
f.seek(0)
line=f.readline()
print(line)
f.close()
#원하는 위치로 옮긴다음에 한줄한줄씩 읽음
# Out:
# 하느님이 보우하사 우리 나라 만세
#
# 동해물과 백두산이 마르고 닳도록

# %% [markdown]
# ### with 문
#
# * 항상 파일을 `open()` 함수로 열고, `close()` 함수로 닫아야 하는 일을 자동으로 처리
# * with문을 이용하면 with 블록 내에서 파일을 열고 벗어나면 파일을 닫음

# %%
f=open("file.txt",'w')
f.write("Hello Python")
f.close()

# %%
with open("file.txt",'w') as f:
  f.write("Hello Python")

# %% [markdown]
# ### [Lab] 표준 입력으로 받은 내용을 파일로 쓰기
#
# * 사용자로부터 표준 입력 받음
# * 받은 내용을 계속 파일 쓰기

# %%
f=open("file.txt",'w')
line=""
while True:
  line=input()
  if not line:break
  f.writelines(line+'\n')

f.close()
# Out:
# 동해물과 백두산이 마르고 닭도록
# 하느님이 보우하사 우리나라 만세

# %%
# !cat file.txt
# Out:
# 동해물과 백두산이 마르고 닭도록
# 하느님이 보우하사 우리나라 만세

# %% [markdown]
# * 이진 파일(이미지) 예제

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f29bbe95-02d7-425f-8089-4e5ae18525bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f29bbe95-02d7-425f-8089-4e5ae18525bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving YKMW1421.JPG to YKMW1421.JPG
# {'YKMW1421.JPG': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe1\x00XExif\x00\x00II*\x00\x08\x00\x00\x00\x02\x00\x12\x01\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00i\x87\x04\x00\x01\x00\x00\x00&\x00\x00\x00\x00\x00\x00\x00\x03\x00\x01\xa0\x03\x00\x01\x00\x00\x00\x01\x00\x00\x00\x02\xa0\x04\x00\x01\x00\x00\x00\x0c\x04\x00\x00\x03\xa0\x04\x00\x01\x00\x00\x00\x00\x05\x00\x00\x00\x00\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x02\x02\x02\x03\x02\x02\x02\x03\x03\x03\x03\x04\x06\x04\x04\x04\x04\x04\x08\x06\x06\x05\x06\t\x08\n\n\t\x08\t\t\n\x0c\x0f\x0c\n\x0b\x0e\x0b\t\t\r\x11\r\x0e\x0f\x10\x10\x11\x10\n\x0c\x12\x13\x12\x10\x13\x0f\x10\x10\x10\xff\xdb\x00C\x01\x03\x03\x03\x04\x03\x04\x08\x04\x04\x08\x10\x0b\t\x0b\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\xff\xc0\x00\x11\x08\x02j\x01\xf4\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfc\xe9S\x8e{\xaddt\xa7bE$\x12G\x1cf\x93*\xe2\xa9;A\x1f\x90\xa9\x04\xfa\xb2Ta\x8c\x86\xe7\xb8#\xad0,E(?)8\xf4\xa8q\xb9\xa2\x96\x96\x11\x18\x03\x8e\x99=hj\xc2\xbd\x85\xc3/#;\xbf\x9d!\x9a6`\x04\x0eW\xa8\xe4\xfaVS\xdc\xde\x9a\xb2/\xc1\x93\x92\xa1r\x0e9\xaceft.\xe8\xb2OG\xd9\xc8<\x8c\x91Qk\xe8S}\xc7\xe43\xe3`8<\x83\xc8>\x956q\xd2\xe3\xb8\xe0_\x95\'%NqF\x8c\x13%W`6\xe3*\xdc\xf3\xde\xa6\xddA\xbe\x82\xab\xfc\xe1<\xc2\xbd\xd4\x9e\x7f\n[j5+2f\x9aD8\xf2\xf99\x07\x1d\x0f\xebJ\xd7\x07-G\xab\xae\xf3\xf2l\xc9\xcf&\x8b\x02}G\xa0\x19-\xb8\xee\xc1\xcf\xbf\xbd!\xe8\xc7\xc74\xb1\xa9N\xa0\x11\xd0\xe3#\xf9P\x92\x1f\xb4{\x0e\xdcw\xe4\x96 \x8c\x8eG"\x84\xbb\x05\xee82\xa88B\xdby\x1e\xd42\xb9\x89IR<\xd8\x90rwc9\x04R\xd4\x1b\xd7DH\x92e6\xb4H\x8cFv\x92p\xdf\xd352M\xeeR\x98\xf6\x05\xe3\x0c\xb2\x93\xd4\x11\x9f\x9b\xdcp(N\xccV\xba\xb8\xe4f\x8c\xb6\x10H\x92.\x0fc\xfa\xf1CW\xd4zGdH\xcc\x1a\x00\x92A)@z\xed\x19\xeb\xfa\xd4\x8a\xfd\x1a\x1e\xd1 \x8fj\x10Q\xbee8\xe0}E8\xbb\xeeW*\xb5\x89m\xcbC\xb9\xa3R\xd0\x94\x04l~Q\xb3\xd8R\x90%bu\x90K\x16\x1as\xb8\x8c\xee\x94\x01\x9fNi>\xf6/\x99=[\x15dR\xe8\'wl\x8c+F\x06\x0f?\xce\x93K\xa09hI\xe5\xc2\x92\x82_hl\xe3r\xe4\x13\x8f^\x82\x93n\xc2\xd9\x92\xad\xb8\x89\xf6%\xc8@\xa7\xe5\xd9\x83\x80zu\xa9\xbd\xf7-\'\xd1\x8f\x05\x90\x934\xae\xfbx\xce\x0e1\xdcUY \xb6\x9a\x92G!\x8fu\xbc.\xa4\x11\xf2\x86\xc2\xe3\x9e\xa0\xf7\xfaRb\xe6\xb6\xc5\x91,\xac\xa69#!\x1b\x0c\x03/\x01\x81\xe7\x9e\xd5,\x1b\xba&v;\xfc\xe2\x91.\x0e\x1b1\x92\x0e~\x8756\x15\xee\xacNH\xba!%\xd8\x8c\xc4d\x85\xdaI\xf5\xa8\xb3\x8e\xc3M\x97aw`\n\x1f\xdeE\xd1\x9e@G\xb8\xe9Q\xd0%y2\xcd\xb5\xf4\x87{\xc70%[k\xc2\x1b8\xe ...

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  sample_data  YKMW1421.JPG

# %% [markdown]
# ### 이진 파일 복사
#
# * 하나의 이진 파일을 읽어서 다른 이진 파일로 쓰기 (복사)

# %%
input = open("YKMW1421.JPG","rb") #파일 모드를 read하는데 바이너리 바일 이므로 b를 붙여 rb
output = open("YKMW1421_copy.JPG","wb") #기록
while True:
  fp = input.read(1)
  if not fp: break
  output.write(fp)

input.close()
output.close()

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  sample_data  YKMW1421_copy.JPG  YKMW1421.JPG

# %% [markdown]
# ## 디렉토리 및 파일 처리

# %% [markdown]
# ### 디렉토리 생성
#
# * 디렉토리와 파일을 다루는 다양한 함수를 제공하는 shutil와 os 라이브러리
# * `mkdir()`: 디렉토리 생성

# %%
#make dir의 약자임
import os
import shutil
os.mkdir('test_')
os.mkdir('test_/1')
os.mkdir('test_/2')
os.mkdir('test_/3')

# %%
# !ls
# Out:
# anthem.txt  file.txt	 test	YKMW1421_copy.JPG
# dan.txt     sample_data  test_	YKMW1421.JPG

# %%
# !ls test_
# Out:
# 1  2  3

# %% [markdown]
# ### 디렉토리 및 파일 복사
#
# * `shutil.copy()`: 파일 복사
# * `shutil.copytree()`: 디렉토리 전체 복사

# %%
import shutil
shutil.copy('YKMW1421.JPG','YKMW1421_copy2.JPG')
# Out:
# 'YKMW1421_copy2.JPG'

# %%
# !ls
# Out:
# anthem.txt  file.txt	 test	YKMW1421_copy2.JPG  YKMW1421.JPG
# dan.txt     sample_data  test_	YKMW1421_copy.JPG

# %%
import shutil
shutil.copytree('test_','test2')
# Out:
# 'test2'

# %%
# !ls
# Out:
# anthem.txt  file.txt	 test	test2		    YKMW1421_copy.JPG
# dan.txt     sample_data  test_	YKMW1421_copy2.JPG  YKMW1421.JPG

# %%
# !ls test2
# Out:
# 1  2  3

# %% [markdown]
# ### 디렉토리 및 파일 확인
#
# * `isdir()`: 디렉토리 존재 확인
# * `isfile()`: 파일 존재 확인
# * `exists()`: 디렉토리/파일 존재 확인

# %%
import os.path
print(os.path.isdir('test_'))
print(os.path.isdir('test_/1'))
print(os.path.isdir('test_/4'))
print(os.path.isfile('YKMW1421.JPG'))
print(os.path.isfile('YKMW1421_copy.JPG'))
print(os.path.isfile('YKMW1421_copy2.JPG'))
print(os.path.exists('test2'))
print(os.path.exists('test2/1'))
print(os.path.exists('test2/4'))
# Out:
# True
# True
# False
# True
# True
# True
# True
# True
# False

# %% [markdown]
# ### 디렉토리 목록 보기
#
# * `os.walk()`: 디렉토리 목록 보기

# %%
import os
for dir_name, dir_list, file_names in os.walk('./'): 
# ./ -> 현재 디렉토리에 대해서 위치 값를 보여주는 것. 유닉스 명령이라고 보면 된다.
  for file_name in file_names:
    print(os.path.join(dir_name,file_name))
# Out:
# ./anthem.txt
# ./YKMW1421.JPG
# ./YKMW1421_copy2.JPG
# ./dan.txt
# ./YKMW1421_copy.JPG
# ./file.txt
# ./.config/gce
# ./.config/.last_survey_prompt.yaml
# ./.config/.last_update_check.json
# ./.config/config_sentinel
# ./.config/.last_opt_in_prompt.yaml
# ./.config/active_config
# ./.config/.metricsUUID
# ./.config/configurations/config_default
# ./.config/logs/2020.06.26/16.26.18.185568.log
# ./.config/logs/2020.06.26/16.25.38.639070.log
# ./.config/logs/2020.06.26/16.26.12.354762.log
# ./.config/logs/2020.06.26/16.25.58.989664.log
# ./.config/logs/2020.06.26/16.26.31.787344.log
# ./.config/logs/2020.06.26/16.26.32.322745.log
# ./sample_data/anscombe.json
# ./sample_data/README.md
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_test.csv
# ./sample_data/california_housing_train.csv

# %% [markdown]
# ### 디렉토리 및 파일 삭제
#
# * `os.remove()`: 파일 삭제
# * `shutil.rmtree()`: 디렉토리 안에 모든 파일/디렉토리 삭제

# %%
import os
os.remove('YKMW1421_copy.JPG')
os.remove('YKMW1421_copy2.JPG')

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  sample_data  test  test_  test2	YKMW1421.JPG

# %%
import shutil
shutil.rmtree('test')
shutil.rmtree('test2')

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  sample_data  YKMW1421.JPG

# %% [markdown]
# ### 파일 크기
#
# * `os.path.getsize()`: 파일의 크기를 바이트 단위로 출력

# %%
import os.path
print(os.path.getsize('YKMW1421.JPG'))
# Out:
# 104955

# %% [markdown]
# ### 파일 압축

# %%
#명령어를 통해서 프로그램환경에서 파일을 압축할 수 있다.
import zipfile
comp = zipfile.ZipFile('new.zip', 'w')
comp.write('YKMW1421.JPG')
comp.close()

# %%
# !ls
# Out:
# anthem.txt  dan.txt  file.txt  new.zip	sample_data  YKMW1421.JPG

# %%
decomp = zipfile.ZipFile('new.zip','r')
decomp.extractall('new')
decomp.close()

# %%
# !ls new
# Out:
# YKMW1421.JPG
